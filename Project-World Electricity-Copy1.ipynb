# %% [markdown]
# __World Electricity Data Analysis Project__

# %% [markdown]
# __Import Libraries__

# %%
import pandas as pd

# %% [markdown]
# __Read and convert Json File to csv__

# %%
data=pd.read_json(r"C:\Users\ROSHAN KAMBLE\Downloads\API_EG.ELC.ACCS.RU.ZS_DS2_en_csv_v2_4364070.json")
data1=data.drop(0)
data1.columns=data1.iloc[0]
data1=data1.drop(1)
data1.reset_index().drop(['index'],axis=1)
data1.to_csv('Electricty_rural.csv',index=False)

# %%
data=pd.read_json(r"C:\Users\ROSHAN KAMBLE\Downloads\API_EG.ELC.ACCS.ZS_DS2_en_csv_v2_4353549.json")
data1=data.drop(0)
data1.columns=data1.iloc[0]
data1=data1.drop(1)
data1.reset_index().drop(['index'],axis=1)
data1.to_csv('Electricty_total.csv',index=False)

# %%
data=pd.read_json(r"C:\Users\ROSHAN KAMBLE\Downloads\API_EG.ELC.ACCS.UR.ZS_DS2_en_csv_v2_4367536.json")
data1=data.drop(0)
data1.columns=data1.iloc[0]
data1=data1.drop(1)
data1.reset_index().drop(['index'],axis=1)
data1.to_csv('Electricty_urban.csv',index=False)

# %%
data=pd.read_json(r"C:\Users\ROSHAN KAMBLE\Downloads\API_EG.ELC.LOSS.ZS_DS2_en_csv_v2_4357259.json")
data1=data.drop(0)
data1.columns=data1.iloc[0]
data1=data1.drop(1)
data1.reset_index().drop(['index'],axis=1)
data1.to_csv('Electricty_PT_lossess.csv',index=False)

# %%
data=pd.read_json(r"C:\Users\ROSHAN KAMBLE\Downloads\API_EG.ELC.NUCL.ZS_DS2_en_csv_v2_4357319.json")
data1=data.drop(0)
data1.columns=data1.iloc[0]
data1=data1.drop(1)
data1.reset_index().drop(['index'],axis=1)
data1.to_csv('Electricty_Nuclear.csv',index=False)

# %%
data=pd.read_json(r"C:\Users\ROSHAN KAMBLE\Downloads\API_EG.ELC.PETR.ZS_DS2_en_csv_v2_4356435.json")
data1=data.drop(0)
data1.columns=data1.iloc[0]
data1=data1.drop(1)
data1.reset_index().drop(['index'],axis=1)
data1.to_csv('Electricty_oil.csv',index=False)

# %%
data=pd.read_json(r"C:\Users\ROSHAN KAMBLE\Downloads\API_EG.ELC.RNWX.KH_DS2_en_csv_v2_4356007.json")
data1=data.drop(0)
data1.columns=data1.iloc[0]
data1=data1.drop(1)
data1.reset_index().drop(['index'],axis=1)
data1.to_csv('Electricty_Renewable.csv',index=False)

# %% [markdown]
# __Assigning variable to sv files to check the data__

# %%
rural=pd.read_csv('Electricty_rural.csv')
urban=pd.read_csv('Electricty_urban.csv')
total=pd.read_csv('Electricty_total.csv')
nuclear=pd.read_csv('Electricty_Nuclear.csv')
oil=pd.read_csv('Electricty_oil.csv')
renewable=pd.read_csv('Electricty_Renewable.csv')
lossess=pd.read_csv('Electricty_PT_lossess.csv')

# %%
rural.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960.0', '1961.0', '1962.0', '1963.0', '1964.0', '1965.0', '1966.0',
#        '1967.0', '1968.0', '1969.0', '1970.0', '1971.0', '1972.0', '1973.0',
#        '1974.0', '1975.0', '1976.0', '1977.0', '1978.0', '1979.0', '1980.0',
#        '1981.0', '1982.0', '1983.0', '1984.0', '1985.0', '1986.0', '1987.0',
#        '1988.0', '1989.0', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021.0',
#        'Unnamed: 66'],
#       dtype='object')

# %%
year_cols=['1960.0', '1961.0', '1962.0', '1963.0', '1964.0', '1965.0', '1966.0',
       '1967.0', '1968.0', '1969.0', '1970.0', '1971.0', '1972.0', '1973.0',
       '1974.0', '1975.0', '1976.0', '1977.0', '1978.0', '1979.0', '1980.0',
       '1981.0', '1982.0', '1983.0', '1984.0', '1985.0', '1986.0', '1987.0',
       '1988.0', '1989.0', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021.0']
year_cols
# Out:
# ['1960.0',
#  '1961.0',
#  '1962.0',
#  '1963.0',
#  '1964.0',
#  '1965.0',
#  '1966.0',
#  '1967.0',
#  '1968.0',
#  '1969.0',
#  '1970.0',
#  '1971.0',
#  '1972.0',
#  '1973.0',
#  '1974.0',
#  '1975.0',
#  '1976.0',
#  '1977.0',
#  '1978.0',
#  '1979.0',
#  '1980.0',
#  '1981.0',
#  '1982.0',
#  '1983.0',
#  '1984.0',
#  '1985.0',
#  '1986.0',
#  '1987.0',
#  '1988.0',
#  '1989.0',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021.0']

# %%
rural.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name     Indicator Code  \
# 0  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 1  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 2  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 3  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
#
#    1960.0  1961.0  1962.0  1963.0  1964.0  1965.0  ...        2013  \
# 0     NaN     NaN     NaN     NaN     NaN     NaN  ...  100.000000
# 1     NaN     NaN     NaN     NaN     NaN     NaN  ...   18.663502
# ...

# %%
urban.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960.0', '1961.0', '1962.0', '1963.0', '1964.0', '1965.0', '1966.0',
#        '1967.0', '1968.0', '1969.0', '1970.0', '1971.0', '1972.0', '1973.0',
#        '1974.0', '1975.0', '1976.0', '1977.0', '1978.0', '1979.0', '1980.0',
#        '1981.0', '1982.0', '1983.0', '1984.0', '1985.0', '1986.0', '1987.0',
#        '1988.0', '1989.0', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021.0',
#        'Unnamed: 66'],
#       dtype='object')

# %%
urban.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name     Indicator Code  \
# 0  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 1  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 2  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 3  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 4  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
#
#    1960.0  1961.0  1962.0  1963.0  1964.0  1965.0  ...        2013  \
# 0     NaN     NaN     NaN     NaN     NaN     NaN  ...  100.000000
# 1     NaN     NaN     NaN     NaN     NaN     NaN  ...   67.112206
# ...

# %%
total.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                             Indicator Name  Indicator Code  1960.0  1961.0  \
# 0  Access to electricity (% of population)  EG.ELC.ACCS.ZS     NaN     NaN
# 1  Access to electricity (% of population)  EG.ELC.ACCS.ZS     NaN     NaN
# 2  Access to electricity (% of population)  EG.ELC.ACCS.ZS     NaN     NaN
# 3  Access to electricity (% of population)  EG.ELC.ACCS.ZS     NaN     NaN
# 4  Access to electricity (% of population)  EG.ELC.ACCS.ZS     NaN     NaN
#
#    1962.0  1963.0  1964.0  1965.0  ...        2013        2014        2015  \
# 0     NaN     NaN     NaN     NaN  ...  100.000000  100.000000  100.000000
# 1     NaN     NaN     NaN     NaN  ...   31.794160   32.001027   33.871910
# ...

# %%
nuclear.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  Electricity production from nuclear sources (%...  EG.ELC.NUCL.ZS   NaN
# 1  Electricity production from nuclear sources (%...  EG.ELC.NUCL.ZS   NaN
# 2  Electricity production from nuclear sources (%...  EG.ELC.NUCL.ZS   NaN
# 3  Electricity production from nuclear sources (%...  EG.ELC.NUCL.ZS   NaN
# 4  Electricity production from nuclear sources (%...  EG.ELC.NUCL.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...      2013      2014  2015  2016.0  \
# 0   NaN   NaN   NaN   NaN   NaN  ...       NaN       NaN   NaN     NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...  3.732574  3.580038   NaN     NaN
# ...

# %%
oil.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  Electricity production from oil sources (% of ...  EG.ELC.PETR.ZS   NaN
# 1  Electricity production from oil sources (% of ...  EG.ELC.PETR.ZS   NaN
# 2  Electricity production from oil sources (% of ...  EG.ELC.PETR.ZS   NaN
# 3  Electricity production from oil sources (% of ...  EG.ELC.PETR.ZS   NaN
# 4  Electricity production from oil sources (% of ...  EG.ELC.PETR.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2013       2014       2015  2016.0  \
# 0   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN     NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...   3.122915   3.193329   3.330766     NaN
# ...

# %%
renewable.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name  Indicator Code  1960.0  \
# 0  Electricity production from renewable sources,...  EG.ELC.RNWX.KH     NaN
# 1  Electricity production from renewable sources,...  EG.ELC.RNWX.KH     NaN
# 2  Electricity production from renewable sources,...  EG.ELC.RNWX.KH     NaN
# 3  Electricity production from renewable sources,...  EG.ELC.RNWX.KH     NaN
# 4  Electricity production from renewable sources,...  EG.ELC.RNWX.KH     NaN
#
#    1961.0  1962.0  1963.0  1964.0  1965.0  ...        2013.0        2014.0  \
# 0     NaN     NaN     NaN     NaN     NaN  ...           NaN           NaN
# 1     NaN     NaN     NaN     NaN     NaN  ...  3.669000e+09  7.687000e+09
# ...

# %%
lossess.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  Electric power transmission and distribution l...  EG.ELC.LOSS.ZS   NaN
# 1  Electric power transmission and distribution l...  EG.ELC.LOSS.ZS   NaN
# 2  Electric power transmission and distribution l...  EG.ELC.LOSS.ZS   NaN
# 3  Electric power transmission and distribution l...  EG.ELC.LOSS.ZS   NaN
# 4  Electric power transmission and distribution l...  EG.ELC.LOSS.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2013       2014  2015.0  2016.0  \
# 0   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN     NaN     NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...  10.393182  10.594766     NaN     NaN
# ...

# %% [markdown]
# __Dropping the null values where complete column is null__

# %%
rural=rural.dropna(axis="columns",how='all')
urban=urban.dropna(axis="columns",how='all')
total=total.dropna(axis="columns",how='all')
nuclear=nuclear.dropna(axis="columns",how='all')
oil=oil.dropna(axis="columns",how='all')
renewable=renewable.dropna(axis="columns",how='all')
lossess=lossess.dropna(axis="columns",how='all')

# %% [markdown]
# __covert years into rows with respect to its values__

# %%
cat_cols=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code']

# %%
year_cols_rural=['1960.0', '1961.0', '1962.0', '1963.0', '1964.0', '1965.0', '1966.0',
       '1967.0', '1968.0', '1969.0', '1970.0', '1971.0', '1972.0', '1973.0',
       '1974.0', '1975.0', '1976.0', '1977.0', '1978.0', '1979.0', '1980.0',
       '1981.0', '1982.0', '1983.0', '1984.0', '1985.0', '1986.0', '1987.0',
       '1988.0', '1989.0', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021.0']

# %%
rural.fillna(0,inplace=True)

# %%
rural1=rural[cat_cols].merge(rural.set_index('Country Code')[year_cols].stack().reset_index(),on='Country Code')
Rural=rural1.rename(columns={'level_1':'Year_Column',0:'Value_Column'})
Rural.head()

# %%
Rural.to_csv('Final_rural.csv',index=False)

# %% [markdown]
# __for Urban__

# %%
years_cols_urban=['1960.0', '1961.0', '1962.0', '1963.0', '1964.0', '1965.0', '1966.0',
       '1967.0', '1968.0', '1969.0', '1970.0', '1971.0', '1972.0', '1973.0',
       '1974.0', '1975.0', '1976.0', '1977.0', '1978.0', '1979.0', '1980.0',
       '1981.0', '1982.0', '1983.0', '1984.0', '1985.0', '1986.0', '1987.0',
       '1988.0', '1989.0', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021.0']

# %%
urban.fillna(0,inplace=True)

# %%
urban1=urban[cat_cols].merge(urban.set_index('Country Code')[year_cols_urban].stack().reset_index(),on='Country Code')
Urban=urban1.rename(columns={'level_1':'Year_Column',0:'Value_Column'})
Urban.head()

# %%
Urban.to_csv('Final_urban.csv',index=True)

# %% [markdown]
# __for Total__

# %%
years_cols_total=[ '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
       '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
       '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
       '2017', '2018', '2019', '2020']

# %%
total.fillna(0,inplace=True)
total

# %%
total1=total[cat_cols].merge(total.set_index('Country Code')[years_cols_total].stack().reset_index(),on='Country Code')
Total=total1.rename(columns={'level_1':'Year_Column',0:'Value_Column'})
Total.head()

# %%
Total.to_csv('Final_Total1.csv',index=False)

# %% [markdown]
# __for_nuclear__

# %%
years_cols_nuclear=['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015']

# %%
nuclear.fillna(0,inplace=True)

# %%
nuclear1=nuclear[cat_cols].merge(nuclear.set_index('Country Code')[years_cols_nuclear].stack().reset_index(),on='Country Code')
Nuclear=nuclear1.rename(columns={'level_1':'Year_Column',0:'Value_Column'})
Nuclear.head()

# %%
Nuclear.to_csv('Final_nuclear.csv',index=False)

# %%
years_cols_oil=['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015']

# %%
oil.fillna(0,inplace=True)

# %%
oil1=oil[cat_cols].merge(oil.set_index('Country Code')[years_cols_oil].stack().reset_index(),on='Country Code')
Oil=oil1.rename(columns={'level_1':'Year_Column',0:'Value_Column'})
Oil.head()

# %%
Oil.to_csv('Final_oil.csv',index=False)

# %% [markdown]
# __for Renewable__

# %%
years_cols_renewable=['1960.0', '1961.0', '1962.0', '1963.0', '1964.0', '1965.0', '1966.0',
       '1967.0', '1968.0', '1969.0', '1970.0', '1971.0', '1972.0', '1973.0',
       '1974.0', '1975.0', '1976.0', '1977.0', '1978.0', '1979.0', '1980.0',
       '1981.0', '1982.0', '1983.0', '1984.0', '1985.0', '1986.0', '1987.0',
       '1988.0', '1989.0', '1990.0', '1991.0', '1992.0', '1993.0', '1994.0',
       '1995.0', '1996.0', '1997.0', '1998.0', '1999.0', '2000.0', '2001.0',
       '2002.0', '2003.0', '2004.0', '2005.0', '2006.0', '2007.0', '2008.0',
       '2009.0', '2010.0', '2011.0', '2012.0', '2013.0', '2014.0', '2015.0']

# %%
renewable.fillna(0,inplace=True)

# %%
renewable1=renewable[cat_cols].merge(renewable.set_index('Country Code')[years_cols_renewable].stack().reset_index(),on='Country Code')
Renewable=renewable1.rename(columns={'level_1':'Year_Column',0:'Value_Column'})
Renewable.head()

# %%
Renewable.to_csv('Final_renewable.csv',index=False)

# %% [markdown]
# __for losses__

# %%
years_cols_losses=['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014']

# %%
lossess.fillna(0,inplace=True)

# %%
losses1=lossess[cat_cols].merge(lossess.set_index('Country Code')[years_cols_losses].stack().reset_index(),on='Country Code')
Losses=losses1.rename(columns={'level_1':'Year_Column',0:'Value_Column'})
Losses.head()

# %%
Losses.dtypes

# %%
Losses.to_csv('Final_losses.csv',index=False)

# %% [markdown]
# __saving the final clean data into different csv file__
